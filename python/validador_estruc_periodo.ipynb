# %%
## IMPORTAMOS LAS LIBRERÍAS NECESARIAS  
import os
import pandas as pd
import numpy as np
import openpyxl
from openpyxl import load_workbook

# %% [markdown]
# ## creación de variable con los datos de las celdas que se compararan

# %%
rangos = pd.read_csv(r'W:\2023\FINANZAS\AI-2023\Codigos NRIP\Codigos\validador de estructura\rangos1.csv')
rangos['Rangos'] = rangos['Rangos'].str.split(',')
# Rellenar con ceros a la izquierda en la columna 'clave' para tener una longitud de 3 caracteres
rangos['ID'] = rangos['ID'].apply(lambda x: str(x).zfill(3))

# Luego, agrupamos los valores por la columna 'clave' y los convertimos en listas
rangos = rangos.groupby('ID')['Rangos'].apply(lambda x: [item for sublist in x for item in sublist]).to_dict()

# %%
#CODIGO BIEN
carpeta = r'W:\2023\FINANZAS\AI-2023\formatos_verificar' #ruta donde se encuentran los formatos de la norma 043

def compara_estructura(carpeta, carpeta1):
    archivos_con_discrepancias = []  # Lista para almacenar los nombres de archivos con discrepancias
    archivos = os.listdir(carpeta)
    for i in os.listdir(carpeta1):
        for archivo in archivos:
            if i[:3] == archivo[:3]:
                ruta1 = os.path.join(carpeta, archivo)
                ruta2 = os.path.join(carpeta1, i)
                try:
                    wb = load_workbook(ruta1)
                    wb2 = load_workbook(ruta2)
                    wb = wb.active
                    wb2 = wb2.active
                    data = []
                    for datos in rangos[f'{i[:3]}']:
                        if wb[f'{datos}'].value != wb2[f'{datos}'].value:
                            data.append(datos)
                        else:
                            pass
                except:
                    print(i, "NO SE PUDO PROCESAR")
                if len(data)>0:
                    archivos_con_discrepancias.append(f'en {i} no coinciden {data}')
    if len(archivos_con_discrepancias)>0:

        rutaentera = os.path.join(ruta,f'{os.path.basename(carpeta1)}.txt')
        with open(rutaentera, "w") as archivo_txt:
            for elemento in archivos_con_discrepancias:
                archivo_txt.write(elemento + "\n")
    else:
        print(f'SIN ERRORES EN LA EMPRESA {os.path.basename(carpeta1)}')

# %%
# si en lugar de comparar una epmresa se quiere revisar si todas las empresas lo hicieron bien
# en un periodo, ejecutar el siguiente codigo en la carpeta que tiene las carpetas de todas
carpetas = input("INSERTE LA RUTA DE LA CARPETA A TRABAJAR")
ruta = input("INSERTE LA RUTA DONDE QUIERE GUARDAR EL ARCHIVO CON ERRORES")
for carp in os.listdir(carpetas):
    carpeta1 = os.path.join(carpetas,carp)
    compara_estructura(carpeta,carpeta1)
# Out:
# SIN ERRORES EN LA EMPRESA AMERICA MOVIL PERU S.A.C
# SIN ERRORES EN LA EMPRESA AMERICATEL PERÚ S.A
# SIN ERRORES EN LA EMPRESA AT & T GLOBAL NETWORK SERVICES DEL PERU S.R.L
# SIN ERRORES EN LA EMPRESA AXESS NETWORKS SOLUTIONS PERU S.A.C
# SIN ERRORES EN LA EMPRESA BANTEL S.A.C
# SIN ERRORES EN LA EMPRESA BFT S.A.C
# SIN ERRORES EN LA EMPRESA BSCP SERVICIOS S.A.C
# SIN ERRORES EN LA EMPRESA CABLE ANDINA S.A.C
# SIN ERRORES EN LA EMPRESA CABLE MASTER COMUNICACIONES S.A.C
# SIN ERRORES EN LA EMPRESA CABLE NETWORD S.R.L
# SIN ERRORES EN LA EMPRESA CABLE PUCALLPA SRL
# SIN ERRORES EN LA EMPRESA CABLE RED PERÚ S.R.L
# SIN ERRORES EN LA EMPRESA CABLE VIDEO PERÚ S.A.C
# SIN ERRORES EN LA EMPRESA CABLE VISION MAGES SAC
# SIN ERRORES EN LA EMPRESA CABLEMAX E.I.R.L
# SIN ERRORES EN LA EMPRESA CABLENORTV S.A.C
# SIN ERRORES EN LA EMPRESA CALA SERVICIOS INTEGRALES E.I.R.L
# SIN ERRORES EN LA EMPRESA CHASQUI@NET S.R.L
# SIN ERRORES EN LA EMPRESA CIRION TECHNOLOGIES PERU S.A
# SIN ERRORES EN LA EMPRESA COLLECTE LOCALISATION SATELLITES PERU S.A.C
# SIN ERRORES EN LA EMPRESA COMPUNETWORK S.A.C
# SIN ERRORES EN LA EMPRESA COMUNICACIONES J&F CABLE TV S.A.C
# SIN ERRORES EN LA EMPRESA CONEXION OPTICA TELECOMUNICACIONES S.A.C
# SIN ERRORES EN LA EMPRESA CONVERGIA PERÚ S.A
# SIN ERRORES EN LA EMPRESA DATOTEL S.A.C
# SIN ERRORES EN LA EMPRESA DIRECTV PERU S.R.L
# SIN ERRORES EN LA EMPRESA ECONOCABLE MEDIA S.A.C
# SIN ERRORES EN LA EMPRESA ECONOCABLE PERÚ S.A.C
# SIN ERRORES EN LA EMPRESA ECONOCABLE S.A.C
# SIN ERRORES EN LA EMPRESA EMPRESA DE TELECOMUNICACIONES MULTIMEDIA ALFA S.A.C
# SIN ERRORES EN LA EMPRESA ENTEL PERÚ S.A
# SIN ERRORES EN LA EMPRESA FIBERLINE PERU S.A.C
# SIN ERRORES EN LA EMPRESA FIBERLUX S.A.C
# SIN ERRORES EN LA EMPRESA FIBERLUX TECH S.A.C
# SIN ERRORES EN LA EMPRESA FIBERTIM S.A.C
# SIN ERRORES EN LA EMPRESA FIBRA MAGIC S.A.C
# SIN ERRORES EN LA EMPRESA FIBRA OPTICA AMAZONICA DEL PERU S.A.C
# SIN ERRORES EN LA EMPRESA GILAT NETWORKS PERU S.A
# SIN ERRORES EN LA EMPRESA GILAT TO HOME PERÚ S.A
# SIN ERRORES EN LA EMPRESA GLOBAL FIBER PERU S.A.C.(ANTES LELITV E.I.R.L.)
# SIN ERRORES EN LA EMPRESA GPON NETWORKS S.A.C
# SIN ERRORES EN LA EMPRESA GTD PERÚ S.A
# SIN ERRORES EN LA EMPRESA HUANUCO TELECOM S.A.C
# SIN ERRORES EN LA EMPRESA HUGHES DE PERÚ S.R.L
# SIN ERRORES EN LA EMPRESA IMPERIAL TV S.A.C
# SIN ERRORES EN LA EMPRESA INGENYO S.A.C
# SIN ERRORES EN LA EMPRESA INTERMAX S.A.C
# SIN ERRORES EN LA EMPRESA INTERNEXA PERÚ S.A
# SIN ERRORES EN LA EMPRESA INVERSIONES MOTUX S.A.C
# SIN ERRORES EN LA EMPRESA INVERSIONES TELCOTEL S.A.C
# SIN ERRORES EN LA EMPRESA IWAY TELECOM S.A.C
# SIN ERRORES EN LA EMPRESA J.R. TELECOM S.R.LTDA
# SIN ERRORES EN LA EMPRESA LATINCABLE S.R.L
# SIN ERRORES EN LA EMPRESA MARAL TELECOMUNICACIONES S.A.C
# SIN ERRORES EN LA EMPRESA MEGACABLE NETWORK S.A.C
# SIN ERRORES EN LA EMPRESA NEXTNET S.A.C
# SIN ERRORES EN LA EMPRESA NOVACLOUD S.A.C
# SIN ERRORES EN LA EMPRESA NOVO TELCO SOLUTIONS S.A.C
# SIN ERRORES EN LA EMPRESA OPTICOM S.A.C
# SIN ERRORES EN LA EMPRESA OROCOM S.A.C
# SIN ERRORES EN LA EMPRESA QITV TELECOMUNICACIONES S.A.C
# SIN ERRORES EN LA EMPRESA RED INTERCABLE PERU S.A.C
# SIN ERRORES EN LA EMPRESA REDES OPTICAS DEL PERÚ S.A.C
# SIN ERRORES EN LA EMPRESA SENCINET LATAM PERU S.A.C
# SIN ERRORES EN LA EMPRESA SORITV S.A.C
# SIN ERRORES EN LA EMPRESA TELECOMUNICACIONES ARGONZA S.R.L
# SIN ERRORES EN LA EMPRESA TELECOMUNICACIONES EL TALLAN E.I.R.L
# SIN ERRORES EN LA EMPRESA TELEFÓNICA DEL PERÚ S.A.A
# SIN ERRORES EN LA EMPRESA TELEINCA S.A.C
# SIN ERRORES EN LA EMPRESA TELESPAZIO ARGENTINA S.A
# SIN ERRORES EN LA EMPRESA TELEVISION SATELITAL CONCEPCION S.R.L
# SIN ERRORES EN LA EMPRESA TELEVISORA DEL SUR S.A.C
# SIN ERRORES EN LA EMPRESA TV NOR COMUNICACIONES S.A.C
# SIN ERRORES EN LA EMPRESA VIETTEL PERU S.A.C
# SIN ERRORES EN LA EMPRESA VOZ Y TELEVISION S.A.C
# SIN ERRORES EN LA EMPRESA WI-NET TELECOM S.A.C
# SIN ERRORES EN LA EMPRESA WIN EMPRESAS S.A.C. (OPTICAL TECHNOLOGIES S.A.C)
# SIN ERRORES EN LA EMPRESA WINNER SYSTEMS S.A.C
# SIN ERRORES EN LA EMPRESA WISP UNITEL S.A.C
# SIN ERRORES EN LA EMPRESA WOW TEL S.A.C
# SIN ERRORES EN LA EMPRESA XIGMA S.A.C
# SIN ERRORES EN LA EMPRESA XIRRUS TEC S.A.C
# SIN ERRORES EN LA EMPRESA YACHAY TELECOMUNICACIONES S.A.C
